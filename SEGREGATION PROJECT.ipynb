# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('C:/Users/KSHITIZ/OneDrive/Desktop/Project1bosch.csv')
df.head(5)
# Out:
#       Pump Type Unnamed: 1                     Unnamed: 2  \
# 0           NaN        NaN                            NaN
# 1           NaN        NaN                            NaN
# 2           NaN        NaN                            NaN
# 3     Pump Type     Volume                     Pump Descp
# 4  0460.423.025        NaN  DISTRIBUTOR PUMP; DI; R1034-1
#
#                                           Unnamed: 3  \
# 0                                  Connector Removal
# 1  1. Tightness checking connector removal \n2. I...
# 2                                        7.416067146
# 3                                        4.449640288
# 4                                                NaN
#
#                                           Unnamed: 4  \
# 0                                                NaN
# 1  1. Tightness checking connector removal \n2. I...
# 2                                                NaN
# 3                                                NaN
# ...

# %%
df.shape
# Out:
# (838, 133)

# %%
df.drop(['Unnamed: 1','Unnamed: 2'],axis=1,inplace=True)

# %%
df.head()
# Out:
#       Pump Type                                         Unnamed: 3  \
# 0           NaN                                  Connector Removal
# 1           NaN  1. Tightness checking connector removal \n2. I...
# 2           NaN                                        7.416067146
# 3     Pump Type                                        4.449640288
# 4  0460.423.025                                                NaN
#
#                                           Unnamed: 4  \
# 0                                                NaN
# 1  1. Tightness checking connector removal \n2. I...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Unnamed: 5  \
# 0                                                NaN
# 1  1) Connector removal\n2) LDA Closer Cap &\n3) ...
# 2                                               39.1
# ...

# %%
df.drop(0,axis=0,inplace=True)

# %%
df
# Out:
#         Pump Type                                         Unnamed: 3  \
# 1             NaN  1. Tightness checking connector removal \n2. I...
# 2             NaN                                        7.416067146
# 3       Pump Type                                        4.449640288
# 4    0460.423.025                                                NaN
# 5    0460.423.037                                                NaN
# ..            ...                                                ...
# 833  0460.424.431                                                NaN
# 834  0460.424.509                                                NaN
# 835  0460.424.513                                                NaN
# 836  0460.424.516                                                NaN
# 837  0460.426.350                                                NaN
#
#                                             Unnamed: 4  \
# 1    1. Tightness checking connector removal \n2. I...
# ...

# %%
df.columns=df.iloc[0]

# %%
df
# Out:
# 1             NaN  \
# 1             NaN
# 2             NaN
# 3       Pump Type
# 4    0460.423.025
# 5    0460.423.037
# ..            ...
# 833  0460.424.431
# 834  0460.424.509
# 835  0460.424.513
# 836  0460.424.516
# 837  0460.426.350
#
# 1   1. Tightness checking connector removal \n2. Inlet connector removal ( OnLy for EDC)\n3. LDA overflow - Special Overflow valve pre- assemble(.025)  \
# 1    1. Tightness checking connector removal \n2. I...
# 2                                          7.416067146
# 3                                          4.449640288
# 4                                                  NaN
# 5                                                  NaN
# ..                                                 ...
# 833                                                NaN
# 834                                                NaN
# 835                                                NaN
# 836                                                NaN
# ...

# %%
df.fillna(0,inplace=True)

# %%
df.head()
# Out:
# 1             0  \
# 1             0
# 2             0
# 3     Pump Type
# 4  0460.423.025
# 5  0460.423.037
#
# 1 1. Tightness checking connector removal \n2. Inlet connector removal ( OnLy for EDC)\n3. LDA overflow - Special Overflow valve pre- assemble(.025)  \
# 1  1. Tightness checking connector removal \n2. I...
# 2                                        7.416067146
# 3                                        4.449640288
# 4                                                  0
# 5                                                  0
#
# 1 1. Tightness checking connector removal \n2. Inlet connector removal ( OnLy for EDC)\n3. LDA overflow - Special Overflow valve pre- assemble(.025)\n4. Cable assembly on VW EDC  \
# 1  1. Tightness checking connector removal \n2. I...
# 2                                                  0
# 3                                                  0
# 4                                                  0
# ...

# %%
df.drop([1,2,3],axis=0,inplace=True)

# %%
df
# Out:
# 1               0  \
# 4    0460.423.025
# 5    0460.423.037
# 6    0460.423.041
# 7    0460.423.048
# 8    0460.423.081
# ..            ...
# 833  0460.424.431
# 834  0460.424.509
# 835  0460.424.513
# 836  0460.424.516
# 837  0460.426.350
#
# 1   1. Tightness checking connector removal \n2. Inlet connector removal ( OnLy for EDC)\n3. LDA overflow - Special Overflow valve pre- assemble(.025)  \
# 4                                                    0
# 5                                                    0
# 6                                                    0
# 7                                                    0
# 8                                                    0
# ..                                                 ...
# 833                                                  0
# 834                                                  0
# 835                                                  0
# 836                                                  0
# ...

# %%
df.replace(to_replace='X',value=1,inplace=True)

# %%
df.reset_index(drop=True,inplace=True)

# %%
df.head()
# Out:
# 1             0  \
# 0  0460.423.025
# 1  0460.423.037
# 2  0460.423.041
# 3  0460.423.048
# 4  0460.423.081
#
# 1  1. Tightness checking connector removal \n2. Inlet connector removal ( OnLy for EDC)\n3. LDA overflow - Special Overflow valve pre- assemble(.025)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
# 1  1. Tightness checking connector removal \n2. Inlet connector removal ( OnLy for EDC)\n3. LDA overflow - Special Overflow valve pre- assemble(.025)\n4. Cable assembly on VW EDC  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# ...

# %%
a=df.columns
str(a).lower()
# Out:
# "index([                                                                                                                                                                                                   0,\n                                                       '1. tightness checking connector removal \\n2. inlet connector removal ( only for edc)\\n3. lda overflow - special overflow valve pre- assemble(.025)',\n                          '1. tightness checking connector removal \\n2. inlet connector removal ( only for edc)\\n3. lda overflow - special overflow valve pre- assemble(.025)\\n4. cable assembly on vw edc',\n                                                                                                                                      '1) connector removal\\n2) lda closer cap &\\n3) sp. ofv pre- assembly',\n                                                                                                '1) connector removal\\n2) lda closer cap\\n3) ksb & head e-lab cable 
# ...

# %%
df.head()
# Out:
# 1             0  \
# 0  0460.423.025
# 1  0460.423.037
# 2  0460.423.041
# 3  0460.423.048
# 4  0460.423.081
#
# 1  1. Tightness checking connector removal \n2. Inlet connector removal ( OnLy for EDC)\n3. LDA overflow - Special Overflow valve pre- assemble(.025)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
# 1  1. Tightness checking connector removal \n2. Inlet connector removal ( OnLy for EDC)\n3. LDA overflow - Special Overflow valve pre- assemble(.025)\n4. Cable assembly on VW EDC  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# ...

# %%
data=df.T

# %%
data.columns=data.iloc[0]

# %%
data.head(110)
# Out:
# 0                                                   0460.423.025  \
# 1
# 0                                                   0460.423.025
# 1. Tightness checking connector removal \n2. In...             0
# 1. Tightness checking connector removal \n2. In...             0
# 1) Connector removal\n2) LDA Closer Cap &\n3) S...             0
# 1) Connector removal\n2) LDA Closer Cap\n3) KSB...             0
# ...                                                          ...
# (1) Assemble Washer & Nut on Drive shaft.\n(2)Y...             0
# (1) Assemble Protection Sleeve ,Washer & Nut on...             0
# (1)Yellow lacquer on 8 points.\n(2) Sealing Cap...             0
# (1)Yellow lacquer on 5 points.\n(2) Sealing Cap...             0
# (1)Yellow lacquer on 6 points.                                 0
#
# 0                                                   0460.423.037  \
# 1
# 0                                                   0460.423.037
# ...

# %%
key=[i for i in range(131)]

# %%
pump_data={}
for i in key:
    pump_data[key[i]]=df.columns[i]
print(pump_data)
# Out:
# {0: 0, 1: '1. Tightness checking connector removal \n2. Inlet connector removal ( OnLy for EDC)\n3. LDA overflow - Special Overflow valve pre- assemble(.025)', 2: '1. Tightness checking connector removal \n2. Inlet connector removal ( OnLy for EDC)\n3. LDA overflow - Special Overflow valve pre- assemble(.025)\n4. Cable assembly on VW EDC', 3: '1) Connector removal\n2) LDA Closer Cap &\n3) Sp. OFV Pre- assembly', 4: '1) Connector removal\n2) LDA Closer Cap\n3) KSB & Head E-lab Cable assembly &\n4) KSB E-lab Nut torqueing', 5: '1) Connector removal\n2) KSB & Head E-lab Cable assembly &\n3) KSB E-lab Nut torqueing', 6: '1) Tightness Checking connector removal &\n2) LDA Closer Cap', 7: '1) Tightness Checking connector removal \n2) LDA Closer Cap\n3) Removal of 2 screw for Fastening plate assembly on LDA (Poti setting + LDA)', 8: '1) Tightness checking Connector removal\n2) LDA Closer Cap (Carb seal)assembly (Pos 475)\n3) Sp. OFV Pre- assembly', 9: '1) Tightness checking Connector removal
# ...

# %%
name=[i for i in data.columns]

# %%
index_data=[]
csv_data=[]
key_data=[]

for j in name:
    for i,value in enumerate(data[j]):
        if value==1:
            key_data.append(i)
    for i in key_data:
        a=pump_data[i]
        csv_data.append(a)
        index_data.append(j)

# %%
b=(pd.DataFrame((index_data,csv_data)).T)
b
# Out:
#                    0                                                  1
# 0       0460.423.037  1) Connector removal\n2) LDA Closer Cap &\n3) ...
# 1       0460.423.037  (1) Caulking\n(2) Black cap on LDA vent fittin...
# 2       0460.423.037  (1) Assemble Protection Sleeve ,Washer & Nut o...
# 3       0460.423.037  (1) Assemble Protection Sleeve, Washer & Nut o...
# 4       0460.423.037                            Pump identification Tag
# ...              ...                                                ...
# 746630  0460.426.350          Potentiometer Fitment on fastening plate
# 746631  0460.426.350                              Potentiometer setting
# 746632  0460.426.350  (1)Yellow lacquer on 8 points.\n(2) Sealing Ca...
# 746633  0460.426.350                            Pump identification Tag
# 746634  0460.426.350  White cap on Vent fitting Benjo (Ex. 0460.424....
#
# [746635 rows x 2 columns]

# %%
b.columns=['pump','operations']

# %%
b
# Out:
#                 pump                                         operations
# 0       0460.423.037  1) Connector removal\n2) LDA Closer Cap &\n3) ...
# 1       0460.423.037  (1) Caulking\n(2) Black cap on LDA vent fittin...
# 2       0460.423.037  (1) Assemble Protection Sleeve ,Washer & Nut o...
# 3       0460.423.037  (1) Assemble Protection Sleeve, Washer & Nut o...
# 4       0460.423.037                            Pump identification Tag
# ...              ...                                                ...
# 746630  0460.426.350          Potentiometer Fitment on fastening plate
# 746631  0460.426.350                              Potentiometer setting
# 746632  0460.426.350  (1)Yellow lacquer on 8 points.\n(2) Sealing Ca...
# 746633  0460.426.350                            Pump identification Tag
# 746634  0460.426.350  White cap on Vent fitting Benjo (Ex. 0460.424....
#
# [746635 rows x 2 columns]

# %%
final_data=b.groupby('pump')['operations'].agg(' '.join).reset_index()
final_data.to_excel('xc.xlsx')
